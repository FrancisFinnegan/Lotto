# %%
import random
import numpy as np
import time

first_play_test = 0
user_points = 0
cpu_points = 0
no_winner_yet = True

def number_input_check(number_input,user_number_list,order):
    while number_input == -1:
        try:
            number_input = int(input(f"Enter {order} number: "))
            while (int(number_input) > 30) | (int(number_input) < 1):
                print('\nPlease enter a number within the range 1-30, inclusive.')
                number_input = input(f"Enter {order} number: ")

        except:
            print('Looks like you didn\'t input a number.\nTry again.')
            number_input = -1
    
    user_number_list.append(int(number_input))

    return number_input


while (no_winner_yet == True):
    if (first_play_test == 0):
    #If this is the first time playing, output the rules
        print('Thank you for playing in the lotto!')
        time.sleep(2)
        print('\n     --> How to play <--     \n')
        time.sleep(2)
        print('You and the computer player select three numbers between 1-30, inclusive.')
        print('The lotto will then select 3 random numbers from the same range.')
        time.sleep(3)
        print('\nThere are two possible ways to earn points:')
        time.sleep(3)
        print('  1) Guessing the number(s) selected')
        print('     a) Guessing 1 number rewards you: 10.')
        print('     b) Guessing 2 numbers rewards you: 50.')
        print('     c) Guessing 3 numbers rewards you: 100!')
        time.sleep(7)
        print('\n  2) If the sum of the lotto numbers and') 
        print('       sum of your numbers are close')
        print('     a) Having a sum within 20 digits rewards you: 10.')
        print('     b) Having a sum within 10 digits rewards you: 50.')
        print('     c) Having a sum within 3 digits rewards you: 100!')
        time.sleep(7)
        print('\nThe first one to 150 wins!')
        time.sleep(3)


    #Select 3 random numbers for the lotto, 1 - 30
    lotto_number_list = []

    for i in range(3):
        lotto_number = np.random.randint(low=1,high=31)
        lotto_number_list.append(lotto_number)
   


    #Computer player selects 3 random numbers, 1 - 30
    cpu_numbers_list = []

    for i in range(3):
        cpu_number = np.random.randint(low=1,high=31)
        cpu_numbers_list.append(cpu_number)
    print('The computer has choosen its numbers...')
    time.sleep(2)


    #User inputs 3 numbers

    user_number_list = []
    user_number_1 = -1
    user_number_2 = -1
    user_number_3 = -1

    user_number_1 = number_input_check(user_number_1,user_number_list,'first') 
    user_number_2 = number_input_check(user_number_2,user_number_list,'second') 
    user_number_3 = number_input_check(user_number_3,user_number_list,'third') 
    time.sleep(1)




    print(f'\nThe numbers the computer player chose are: {cpu_numbers_list[0]}, {cpu_numbers_list[1]}, {cpu_numbers_list[2]}')
    print(f'The sum of its numbers is {cpu_numbers_list[0] + cpu_numbers_list[1] + cpu_numbers_list[2]}')
    time.sleep(5)

    #Check the inputs against the lotto numbers
    user_correct_number_chosen = 0
    user_correct_number_list = []

    cpu_correct_number_chosen = 0
    cpu_correct_number_list = []

    for i in lotto_number_list:
        for j in user_number_list:
            if j == i:
                user_correct_number_chosen += 1
                user_correct_number_list.append(i)
        for j in cpu_numbers_list:
            if j == i:
                cpu_correct_number_chosen += 1
                cpu_correct_number_list.append(i)




    #Present the lotto numbers
    print('\nWinning lotto numbers for this round are:')
    time.sleep(1)
    print(lotto_number_list[0])
    time.sleep(1)
    print(lotto_number_list[1])
    time.sleep(1)
    print(lotto_number_list[2])
    time.sleep(1)
    print(f'The sum of the lotto numbers is {lotto_number_list[0] + lotto_number_list[1] + lotto_number_list[2]}')
    time.sleep(2)




    print(f'\nThe numbers you chose were: {user_number_1}, {user_number_2}, {user_number_3}')
    time.sleep(2)
    print(f'The sum of your numbers is {user_number_list[0] + user_number_list[1] + user_number_list[2]}')
    time.sleep(2)



    print('\n---------Same number category---------')
    if (user_correct_number_chosen == 3):
        print('\n*****Congratulatons! You guessed all three correct!')
        print('*****You win 100 points!')
        user_points += 100
    elif (user_correct_number_chosen == 2):
        print(f'\n*****Congratulatons! You guessed two correct! --> {user_correct_number_list[0]} and {correct_number_list[1]}')
        print('*****You win 50 points!')    
        user_points += 10
    elif (user_correct_number_chosen == 1):
        print(f'\n*****Congratulatons! You guessed one correct! --> {user_correct_number_list[0]}')
        print('*****You win 10 points!')    
        user_points += 10
    else:
        print('None of the numbers you chose were on the lotto list this time around.')


    # Add up the cpu's points
    if (cpu_correct_number_chosen == 3):
        cpu_points_this_round = 100
        cpu_points += 100
    elif (cpu_correct_number_chosen == 2):
        cpu_points_this_round = 50
        cpu_points += 50
    elif (cpu_correct_number_chosen == 1):
        cpu_points_this_round = 10
        cpu_points += 10
    else:
        cpu_points_this_round = 0

    print(f'\nPoints earned by the computer player in this category: {cpu_points_this_round}')
    time.sleep(3)


    lotto_number_sum = 0
    for i in lotto_number_list:
        lotto_number_sum += i

    user_lotto_sum = 0
    for j in user_number_list:
        user_lotto_sum += j

    cpu_lotto_sum = 0
    for k in cpu_numbers_list:
        cpu_lotto_sum += k


    if lotto_number_sum > user_lotto_sum:
        higher_number = lotto_number_sum
        lower_number = user_lotto_sum
    else:
        lower_number = lotto_number_sum
        higher_number = user_lotto_sum



    print('\n---------Sum of number category---------')
    if ((higher_number - lower_number) <= 3):
        print('*****Congratulatons! You guessed within 3 digits of the sum of the numbers!')
        print('*****Grand prize!')
        print('*****You win 100 points!\n')
        user_points += 100
    elif ((higher_number - lower_number) <= 10):
        print('*****Congratulatons! You guessed within 10 digits of the sum of the numbers!')
        print('*****You win 50 points!\n')
        user_points += 50
    elif ((higher_number - lower_number) <= 20):
        print('*****Congratulatons! You guess within 20 digits of the sum of the numbers!')
        print('*****You win 10 points!\n')
        user_points += 10
    else:
        print('\nThe sum of your numbers were not close enough for any points.\n')



    if lotto_number_sum > cpu_lotto_sum:
        higher_number = lotto_number_sum
        lower_number = cpu_lotto_sum
    else:
        lower_number = lotto_number_sum
        higher_number = cpu_lotto_sum

    if ((higher_number - lower_number) <= 3):
        cpu_points_this_round = 100
        cpu_points += 100
    elif ((higher_number - lower_number) <= 10):
        cpu_points_this_round = 50
        cpu_points += 50
    elif ((higher_number - lower_number) <= 20):
        cpu_points_this_round = 10
        cpu_points += 10
    else:
        cpu_points_this_round = 0


    print(f'Points earned by the computer player in this category: {cpu_points_this_round}')
    time.sleep(3)



    print(f'\nRunning total:\n\tUsers points: {user_points}\n\tComputer players points: {cpu_points}')
    time.sleep(2)


    if ((cpu_points >= 150) | (user_points >= 150)):
        if (user_points >= 150):
            print('You win!')
        else:
            print('The computer wins this time...\nBetter luck next time!')
        no_winner_yet = False
    else:
        print('\n\n----------\nNext Round:\n')


    first_play_test = 1
# Out:
# Thank you for playing in the lotto!
#
#      --> How to play <--
#
# You and the computer player select three numbers between 1-30, inclusive.
# The lotto will then select 3 random numbers from the same range.
#
# There are two possible ways to earn points:
#   1) Guessing the number(s) selected
#      a) Guessing 1 number rewards you: 10.
#      b) Guessing 2 numbers rewards you: 50.
#      c) Guessing 3 numbers rewards you: 100!
